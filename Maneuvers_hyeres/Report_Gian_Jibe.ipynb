# %% [markdown]
# ### Gian, Jibe

# %%
from Report_with_eval import *

# %%
main(df, 'Gian',"Jibe");
# Out:
#  === Evaluating Gian - Run: 30_11_2025_Run11 - Maneuver 8 ===
# Reference VMG before maneuver: 20.39 | Reference SOG before maneuver: 28.43
# Integrated distance (VMG): 156.11 m | Integrated distance (SOG): 180.82 m
# Expected distance if reference speed maintained (VMG): 146.88 m | Expected distance if reference speed maintained (SOG): 204.75 m
# Distance lost (VMG): -9.22 m | Distance lost (SOG): 23.93 m
# Ratio Path/AB: 1.143 | Sign of VMG loss: -1.0 (1=positive, -1=negative, 0=neutral), from VMGbefore-VMGreal=-9.22 m
#
#
#  === Evaluating Gian - Run: 30_11_2025_Run11 - Maneuver 9 ===
# Reference VMG before maneuver: 26.91 | Reference SOG before maneuver: 29.52
# Integrated distance (VMG): 162.05 m | Integrated distance (SOG): 184.85 m
# Expected distance if reference speed maintained (VMG): 195.13 m | Expected distance if reference speed maintained (SOG): 214.03 m
# Distance lost (VMG): 33.08 m | Distance lost (SOG): 29.18 m
# ...
