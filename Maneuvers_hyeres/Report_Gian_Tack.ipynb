# %% [markdown]
# ### Gian, Tack

# %%
from Report_with_eval import *

# %%
main(df, 'Gian',"Tack");
# Out:
#  === Evaluating Gian - Run: 30_11_2025_Run11 - Maneuver 2 ===
# Reference VMG before maneuver: 18.33 | Reference SOG before maneuver: 22.18
# Integrated distance (VMG): 98.24 m | Integrated distance (SOG): 135.84 m
# Expected distance if reference speed maintained (VMG): 132.02 m | Expected distance if reference speed maintained (SOG): 159.76 m
# Distance lost (VMG): 33.78 m | Distance lost (SOG): 23.92 m
# Ratio Path/AB: 1.244 | Sign of VMG loss: 1.0 (1=positive, -1=negative, 0=neutral), from VMGbefore-VMGreal=33.78 m
#
#
#  === Evaluating Gian - Run: 30_11_2025_Run11 - Maneuver 3 ===
# Reference VMG before maneuver: 14.90 | Reference SOG before maneuver: 24.00
# Integrated distance (VMG): 114.13 m | Integrated distance (SOG): 149.04 m
# Expected distance if reference speed maintained (VMG): 108.14 m | Expected distance if reference speed maintained (SOG): 174.13 m
# Distance lost (VMG): -6.00 m | Distance lost (SOG): 25.08 m
# ...
