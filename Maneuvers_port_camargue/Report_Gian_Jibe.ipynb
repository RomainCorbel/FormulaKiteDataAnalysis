# %% [markdown]
# ### Gian, Jibe

# %%
from Report_with_eval import *

# %%
main(df, 'Gian',"Jibe");
# Out:
#  === Evaluating Gian - Run: 08_06_2025_Run1 - Maneuver 5 ===
# Reference VMG before maneuver: 13.38 | Reference SOG before maneuver: 25.09
# Integrated distance (VMG): 130.84 m | Integrated distance (SOG): 166.25 m
# Expected distance if reference speed maintained (VMG): 97.05 m | Expected distance if reference speed maintained (SOG): 181.99 m
# Distance lost (VMG): -33.78 m | Distance lost (SOG): 15.74 m
# Ratio Path/AB: 1.227 | Sign of VMG loss: -1.0 (1=positive, -1=negative, 0=neutral), from VMGbefore-VMGreal=-33.78 m
#
#
#  === Evaluating Gian - Run: 08_06_2025_Run1 - Maneuver 6 ===
# Reference VMG before maneuver: 20.58 | Reference SOG before maneuver: 26.22
# Integrated distance (VMG): 121.34 m | Integrated distance (SOG): 151.95 m
# Expected distance if reference speed maintained (VMG): 148.30 m | Expected distance if reference speed maintained (SOG): 188.93 m
# Distance lost (VMG): 26.96 m | Distance lost (SOG): 36.98 m
# ...
