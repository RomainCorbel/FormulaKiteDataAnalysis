# %% [markdown]
# ### Karl, Jibe

# %%
from Report_with_eval import *

# %%
main(df, 'Karl',"Jibe");
# Out:
#  === Evaluating Karl - Run: 08_06_2025_Run1 - Maneuver 13 ===
# Reference VMG before maneuver: 18.87 | Reference SOG before maneuver: 26.22
# Integrated distance (VMG): 128.19 m | Integrated distance (SOG): 168.80 m
# Expected distance if reference speed maintained (VMG): 135.94 m | Expected distance if reference speed maintained (SOG): 188.85 m
# Distance lost (VMG): 7.75 m | Distance lost (SOG): 20.04 m
# Ratio Path/AB: 1.239 | Sign of VMG loss: 1.0 (1=positive, -1=negative, 0=neutral), from VMGbefore-VMGreal=7.75 m
#
#
#  === Evaluating Karl - Run: 08_06_2025_Run2 - Maneuver 5 ===
# Reference VMG before maneuver: 19.23 | Reference SOG before maneuver: 25.55
# Integrated distance (VMG): 116.47 m | Integrated distance (SOG): 158.12 m
# Expected distance if reference speed maintained (VMG): 138.48 m | Expected distance if reference speed maintained (SOG): 184.05 m
# Distance lost (VMG): 22.00 m | Distance lost (SOG): 25.93 m
# ...
