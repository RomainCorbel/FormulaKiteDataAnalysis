# %% [markdown]
# ### Gian, Tack

# %%
from Report_with_eval import *

# %%
main(df, 'Gian',"Tack");
# Out:
#  === Evaluating Gian - Run: 08_06_2025_Run1 - Maneuver 1 ===
# Reference VMG before maneuver: 11.85 | Reference SOG before maneuver: 18.19
# Integrated distance (VMG): 93.07 m | Integrated distance (SOG): 125.22 m
# Expected distance if reference speed maintained (VMG): 85.35 m | Expected distance if reference speed maintained (SOG): 130.98 m
# Distance lost (VMG): -7.73 m | Distance lost (SOG): 5.76 m
# Ratio Path/AB: 1.312 | Sign of VMG loss: -1.0 (1=positive, -1=negative, 0=neutral), from VMGbefore-VMGreal=-7.73 m
#
#
#  === Evaluating Gian - Run: 08_06_2025_Run1 - Maneuver 8 ===
# Reference VMG before maneuver: 8.98 | Reference SOG before maneuver: 17.34
# Integrated distance (VMG): 99.66 m | Integrated distance (SOG): 135.11 m
# Expected distance if reference speed maintained (VMG): 65.14 m | Expected distance if reference speed maintained (SOG): 125.85 m
# Distance lost (VMG): -34.52 m | Distance lost (SOG): -9.27 m
# ...
