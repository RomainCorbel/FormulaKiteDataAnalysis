# %% [markdown]
# ### Karl, Tack

# %%
from Report_with_eval import *

# %%
main(df, 'Karl',"Tack");
# Out:
#  === Evaluating Karl - Run: 08_06_2025_Run1 - Maneuver 1 ===
# Reference VMG before maneuver: 9.87 | Reference SOG before maneuver: 20.79
# Integrated distance (VMG): 86.68 m | Integrated distance (SOG): 119.96 m
# Expected distance if reference speed maintained (VMG): 71.06 m | Expected distance if reference speed maintained (SOG): 149.71 m
# Distance lost (VMG): -15.62 m | Distance lost (SOG): 29.75 m
# Ratio Path/AB: 1.347 | Sign of VMG loss: -1.0 (1=positive, -1=negative, 0=neutral), from VMGbefore-VMGreal=-15.62 m
#
#
#  === Evaluating Karl - Run: 08_06_2025_Run1 - Maneuver 9 ===
# Reference VMG before maneuver: 7.64 | Reference SOG before maneuver: 16.05
# Integrated distance (VMG): 94.91 m | Integrated distance (SOG): 128.42 m
# Expected distance if reference speed maintained (VMG): 55.03 m | Expected distance if reference speed maintained (SOG): 115.60 m
# Distance lost (VMG): -39.88 m | Distance lost (SOG): -12.82 m
# ...
