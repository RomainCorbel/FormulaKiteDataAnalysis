# %%
import os
import json
from start_analysis import analyze_session
from natsort import natsorted
summary = []

base_dir = "../Data_Sailnjord/Hyères November 2025/Starts"

# Scan de tous les dossiers de date
target_folders = ["30_11_2025"]

# On filtre pour ne garder que les dossiers présents qui sont dans notre liste
for date_folder in sorted([f for f in os.listdir(base_dir) if f in target_folders]):
    date_path = os.path.join(base_dir, date_folder)

    # Scan de tous les runs dans chaque dossier de date
    for run_folder in natsorted(os.listdir(date_path)):
        run_path = os.path.join(date_path, run_folder)
        target_files = ["Gian Stragiotti.csv"]
        csv_files = [f for f in os.listdir(run_path) if f in target_files]
        if not csv_files:
            continue
        else:
            file_full_path = os.path.join(run_path, csv_files[0])
            print(f"Analyse: {file_full_path} dans {run_path}")
            try:
                longest_intervals = analyze_session(
                    file_full_path,
                    smoothing_window_sec=5.0,
                    min_duration_sec=30.0,
                    sog_derivative_threshold=0.3,
                    run_folder=run_folder
                    )
                summary.append({
                    "run": run_folder,
                    "intervals": longest_intervals
                })
            except Exception as e:
                print(f"Erreur dans {run_path} : {e}")
# Out:
# Analyse: ../Data_Sailnjord/Hyères November 2025/Starts\30_11_2025\30_11_2025_Run1\Gian Stragiotti.csv dans ../Data_Sailnjord/Hyères November 2025/Starts\30_11_2025\30_11_2025_Run1
# Avg TWA: 37.25°, Avg TWS: 11.08 kts
# --- Metrics ---
# SOG_ref_polar - SOG Max: 0.90 knots
# Slope: 2.5023 knots/s
# SOG max - SOG min: 14.28 knots
# Time for 98%: -1.30 seconds
# Analyse: ../Data_Sailnjord/Hyères November 2025/Starts\30_11_2025\30_11_2025_Run2\Gian Stragiotti.csv dans ../Data_Sailnjord/Hyères November 2025/Starts\30_11_2025\30_11_2025_Run2
# Avg TWA: 33.96°, Avg TWS: 10.22 kts
# --- Metrics ---
# SOG_ref_polar - SOG Max: 0.80 knots
# Slope: 2.5654 knots/s
# SOG max - SOG min: 13.08 knots
# Time for 98%: 6.70 seconds
# Analyse: ../Data_Sailnjord/Hyères November 2025/Starts\30_11_2025\30_11_2025_Run3\Gian Stragiotti.csv dans ../Data_Sailnjord/Hyères November 2025/Starts\30_11_2025\30_11_2025_Run3
# Avg TWA: 34.33°, Avg TWS: 9.06 kts
# --- Metrics ---
# SOG_ref_polar - SOG Max: -0.57 knots
# Slope: 2.2404 knots/s
# SOG max - SOG min: 14.42 knots
# Time for 98%: 7.80 seconds
# Analyse: ../Data_Sailnjord/Hyères November 2025/Starts\30_11_2025\30_11_2025_Run4\Gian Stragiotti.csv dans ../Data_Sailnjord/Hyères November 2025/Starts\30_11_2025\30_11_2025_Run4
# Avg TWA: 44.20°, Avg TWS: 13.84 kts
# --- Metrics ---
# SOG_ref_polar - SOG Max: 0.77 knots
# Slope: 2.3365 knots/s
# SOG max - SOG min: 12.99 knots
# Time for 98%: 1.81 seconds
# Analyse: ../Data_Sailnjord/Hyères November 2025/Starts\30_11_2025\30_11_2025_Run5\Gian Stragiotti.csv dans ../Data_Sailnjord/Hyères November 2025/Starts\30_11_2025\30_11_2025_Run5
# Avg TWA: 38.33°, Avg TWS: 9.82 kts
# --- Metrics ---
# SOG_ref_polar - SOG Max: -0.77 knots
# Slope: 2.6131 knots/s
# SOG max - SOG min: 14.56 knots
# Time for 98%: 9.60 seconds
# Analyse: ../Data_Sailnjord/Hyères November 2025/Starts\30_11_2025\30_11_2025_Run6\Gian Stragiotti.csv dans ../Data_Sailnjord/Hyères November 2025/Starts\30_11_2025\30_11_2025_Run6
# Avg TWA: 39.99°, Avg TWS: 9.28 kts
# --- Metrics ---
# SOG_ref_polar - SOG Max: -0.06 knots
# Slope: 2.2381 knots/s
# SOG max - SOG min: 11.65 knots
# Time for 98%: 4.50 seconds
# Analyse: ../Data_Sailnjord/Hyères November 2025/Starts\30_11_2025\30_11_2025_Run7\Gian Stragiotti.csv dans ../Data_Sailnjord/Hyères November 2025/Starts\30_11_2025\30_11_2025_Run7
# Avg TWA: 43.90°, Avg TWS: 9.70 kts
# --- Metrics ---
# SOG_ref_polar - SOG Max: -0.58 knots
# Slope: 2.5859 knots/s
# SOG max - SOG min: 15.01 knots
# Time for 98%: 12.20 seconds
# Analyse: ../Data_Sailnjord/Hyères November 2025/Starts\30_11_2025\30_11_2025_Run8\Gian Stragiotti.csv dans ../Data_Sailnjord/Hyères November 2025/Starts\30_11_2025\30_11_2025_Run8
# Avg TWA: 42.52°, Avg TWS: 10.39 kts
# --- Metrics ---
# SOG_ref_polar - SOG Max: -0.10 knots
# Slope: 2.5758 knots/s
# SOG max - SOG min: 11.92 knots
# Time for 98%: 8.38 seconds
# Analyse: ../Data_Sailnjord/Hyères November 2025/Starts\30_11_2025\30_11_2025_Run9\Gian Stragiotti.csv dans ../Data_Sailnjord/Hyères November 2025/Starts\30_11_2025\30_11_2025_Run9
# Avg TWA: 30.26°, Avg TWS: 10.34 kts
# --- Metrics ---
# SOG_ref_polar - SOG Max: 1.00 knots
# Slope: 2.1801 knots/s
# SOG max - SOG min: 12.79 knots
# Time for 98%: 11.01 seconds
# Analyse: ../Data_Sailnjord/Hyères November 2025/Starts\30_11_2025\30_11_2025_Run10\Gian Stragiotti.csv dans ../Data_Sailnjord/Hyères November 2025/Starts\30_11_2025\30_11_2025_Run10
# Avg TWA: 36.55°, Avg TWS: 8.53 kts
# --- Metrics ---
# SOG_ref_polar - SOG Max: 0.23 knots
# Slope: 0.7037 knots/s
# SOG max - SOG min: 12.98 knots
# Time for 98%: 7.50 seconds
