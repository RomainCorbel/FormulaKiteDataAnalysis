# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import scipy.stats as stats

def t_test(df1, df2, target="SOG"):
    t_stat, p_value = stats.ttest_ind(df1[target].dropna(), df2[target].dropna())
    print(f"T-statistic: {t_stat:.3f}, p-value: {p_value:.15f}")
    
    # If p-value is less than 0.05, the difference is statistically significant
    if p_value < 0.05:
        print("The difference is statistically significant, keeping data split.")
    else:
        print("The difference is not statistically significant, keeping data combined.")

def print_run_stats(first_sentence, first_runs_df, last_runs_df, target):
    print("\n", first_sentence)

    if first_runs_df[target].dtype == "O":
        first_target = ", ".join(first_runs_df[target].dropna().unique())
        last_target = ", ".join(last_runs_df[target].dropna().unique())
    else:
        first_target = f"{first_runs_df[target].mean():.2f}"
        last_target = f"{last_runs_df[target].mean():.2f}"

    print(f"Mean {target } on the first group : {first_target}, "
          f"average SOG: {first_runs_df['SOG'].mean():.2f}, std SOG: {first_runs_df['SOG'].std():.2f}")
    
    print(f"Mean  {target } on the second group : {last_target}, "
          f"average SOG: {last_runs_df['SOG'].mean():.2f}, std SOG: {last_runs_df['SOG'].std():.2f}")

# %%
df = pd.read_csv("all_data.csv")

# %%
data_25_11 = df[df["ISODateTimeUTC"].str.startswith("2025-11-25")]
data_26_11 = df[df["ISODateTimeUTC"].str.startswith("2025-11-26")]
data_27_11 = df[df["ISODateTimeUTC"].str.startswith("2025-11-27")]

# %%
t_test(data_25_11,data_26_11, target="TWS")
print_run_stats("Runs 1 to 5 VS Runs 6 to 10:", data_25_11, data_26_11, target="TWS")
# Out:
# T-statistic: 247.753, p-value: 0.000000000000000
# The difference is statistically significant, keeping data split.
#
#  Runs 1 to 5 VS Runs 6 to 10:
# Mean TWS on the first group : 22.47, average SOG: 23.70, std SOG: 4.95
# Mean  TWS on the second group : 15.81, average SOG: 25.28, std SOG: 6.80

# %%
t_test(data_27_11,data_26_11, target="TWS")
print_run_stats("Runs 1 to 5 VS Runs 6 to 10:", data_27_11, data_26_11, target="TWS")
# Out:
# T-statistic: -109.053, p-value: 0.000000000000000
# The difference is statistically significant, keeping data split.
#
#  Runs 1 to 5 VS Runs 6 to 10:
# Mean TWS on the first group : 14.15, average SOG: 25.90, std SOG: 5.46
# Mean  TWS on the second group : 15.81, average SOG: 25.28, std SOG: 6.80

# %% [markdown]
# ## t test Max levi vs karl chub per day

# %%
Only_Max_Day1 = data_25_11[(data_25_11["boat_name"] == "Max Maeder")]
Only_Max_Day1["boat_name"].sample(5)

Only_Max_Day2 = data_26_11[(data_26_11["boat_name"] == "Max Maeder")]
Only_Max_Day2["boat_name"].sample(5)

Only_Max_Day3 = data_27_11[(data_27_11["boat_name"] == "Max Maeder")]
Only_Max_Day3["boat_name"].sample(5)
# Out:
# 66098    Max Maeder
# 52597    Max Maeder
# 70891    Max Maeder
# 54083    Max Maeder
# 73365    Max Maeder
# Name: boat_name, dtype: object

# %%
Only_Max_Day1_Levi = Only_Max_Day1[Only_Max_Day1["mast_brand"] == "Levi"]
Only_Max_Day1_Chub = Only_Max_Day1[Only_Max_Day1["mast_brand"] == "Chub"]
t_test(Only_Max_Day1_Levi,Only_Max_Day1_Chub) #upwind
print_run_stats("Gian on chub downwind VS Gian on levi downwind:", Only_Max_Day1_Levi, Only_Max_Day1_Chub, target="mast_brand")
# Out:
# T-statistic: 1.821, p-value: 0.068641116194975
# The difference is not statistically significant, keeping data combined.
#
#  Gian on chub downwind VS Gian on levi downwind:
# Mean mast_brand on the first group : Levi, average SOG: 23.93, std SOG: 4.77
# Mean  mast_brand on the second group : Chub, average SOG: 23.69, std SOG: 5.26

# %%
Only_Max_Day2_Levi = Only_Max_Day2[Only_Max_Day2["mast_brand"] == "Levi"]
Only_Max_Day2_Chub = Only_Max_Day2[Only_Max_Day2["mast_brand"] == "Chub"]
t_test(Only_Max_Day2_Levi,Only_Max_Day2_Chub) #upwind
print_run_stats("Gian on chub downwind VS Gian on levi downwind:", Only_Max_Day2_Levi, Only_Max_Day2_Chub, target="mast_brand")
# Out:
# T-statistic: 31.109, p-value: 0.000000000000000
# The difference is statistically significant, keeping data split.
#
#  Gian on chub downwind VS Gian on levi downwind:
# Mean mast_brand on the first group : Levi, average SOG: 25.79, std SOG: 6.71
# Mean  mast_brand on the second group : Chub, average SOG: 22.28, std SOG: 9.01

# %%
Only_Max_Day3_Levi = Only_Max_Day3[Only_Max_Day3["mast_brand"] == "Levi"]
print(Only_Max_Day3_Levi)
Only_Max_Day3_Chub = Only_Max_Day3[Only_Max_Day3["mast_brand"] == "Chub"]
print(Only_Max_Day3_Chub)
t_test(Only_Max_Day3_Levi,Only_Max_Day3_Chub) #upwind
print_run_stats("Gian on chub downwind VS Gian on levi downwind:", Only_Max_Day3_Levi, Only_Max_Day3_Chub, target="mast_brand")
# Out:
#                  ISODateTimeUTC  SecondsSince1970   SOG      TWA     TWS  \
# 49001  2025-11-27T07:52:53.960Z      1.764230e+09  21.6   32.496  15.396
# 49002  2025-11-27T07:52:54.056Z      1.764230e+09  21.7   34.900  15.400
# 49003  2025-11-27T07:52:54.160Z      1.764230e+09  21.7   34.500  15.400
# 49004  2025-11-27T07:52:54.260Z      1.764230e+09  21.7   32.500  15.400
# 49005  2025-11-27T07:52:54.359Z      1.764230e+09  21.6   32.100  15.400
# ...                         ...               ...   ...      ...     ...
# 76795  2025-11-27T09:28:01.855Z      1.764236e+09  33.8 -165.000  15.457
# 76796  2025-11-27T09:28:01.954Z      1.764236e+09  33.9 -165.600  15.486
# 76797  2025-11-27T09:28:02.053Z      1.764236e+09  34.0 -166.505  15.505
# 76798  2025-11-27T09:28:02.158Z      1.764236e+09  33.9 -162.316  15.516
# 76799  2025-11-27T09:28:02.256Z      1.764236e+09  33.8 -164.226  15.526
#
#            TWD  BelowLineCalc  central    COG  COG_Mag  ...  M_back_X  \
# 49001    0.896            NaN   89.826  328.4    325.4  ...  2198.970
# 49002    0.900            NaN  103.200  326.0    323.0  ...  2738.451
# 49003    0.900            NaN  122.400  326.4    323.4  ...  2814.371
# 49004    0.900            NaN  143.100  328.4    325.4  ...  1580.537
# 49005    0.900            NaN  141.500  328.8    325.8  ...  1647.522
# ...        ...            ...      ...    ...      ...  ...       ...
# 76795  332.200            NaN   68.600  137.2    134.2  ...  -762.430
# 76796  332.200            NaN   68.650  137.8    134.8  ... -1233.674
# 76797  332.195            NaN   68.700  138.7    135.7  ... -1700.206
# 76798  332.184            NaN   66.200  134.5    131.5  ... -1200.217
# 76799  332.174            NaN   69.417  136.4    133.4  ... -2588.363
#
#        M_back_Y  M_front_X  M_front_Y    M_tot_X    M_tot_Y  P_back_X  \
# 49001  -887.590   8588.561    701.205  10787.530    829.780   -12.088
# 49002  -904.930   9236.083    827.462  11974.535   1542.661   -10.806
# 49003  -766.763   8342.548   -241.699  11156.919   3325.833    -8.433
# 49004  -732.887   8199.257    -63.678   9779.794   2148.543    -8.880
# 49005  -760.783   7784.125   -210.238   9431.646   1007.138    -9.866
# ...         ...        ...        ...        ...        ...       ...
# 76795  -712.993  -5239.600  -3292.319  -6002.031 -13780.858   -14.351
# 76796  -825.081  -4902.069  -3013.665  -6135.743 -13992.720   -20.186
# 76797  -936.049  -4567.913  -2737.797  -6268.119 -14202.463   -25.963
# 76798  -964.714  -4062.602  -3821.686  -5262.819 -14935.846   -20.759
# 76799 -1263.796  -4946.264  -3010.904  -7534.627 -11907.818   -24.124
#
#        P_back_Y  P_front_X  P_front_Y
# 49001   -28.808     10.510   -130.801
# 49002   -32.355     11.240   -125.999
# 49003   -30.901     -3.429   -115.323
# 49004   -19.150     -0.929   -120.505
# 49005   -21.372     -3.501   -119.271
# ...         ...        ...        ...
# 76795    15.546    -50.234     79.969
# 76796    31.579    -50.043     81.610
# 76797    47.452    -49.854     83.235
# 76798    25.213    -61.852     65.783
# 76799    49.240    -48.952     80.434
#
# [8997 rows x 75 columns]
#                  ISODateTimeUTC  SecondsSince1970   SOG     TWA     TWS  \
# 58758  2025-11-27T08:28:29.051Z      1.764232e+09  20.3  26.920  15.905
# 58759  2025-11-27T08:28:29.160Z      1.764232e+09  20.4  27.564  15.916
# 58760  2025-11-27T08:28:29.256Z      1.764232e+09  20.3  27.603  15.926
# 58761  2025-11-27T08:28:29.357Z      1.764232e+09  20.4  27.443  15.936
# 58762  2025-11-27T08:28:29.446Z      1.764232e+09  20.4  26.678  15.945
# ...                         ...               ...   ...     ...     ...
# 68185  2025-11-27T08:51:54.856Z      1.764234e+09   1.7 -96.014  16.358
# 68186  2025-11-27T08:51:54.946Z      1.764234e+09   1.2 -79.605  16.322
# 68187  2025-11-27T08:51:55.072Z      1.764234e+09   1.7 -63.193  16.300
# 68188  2025-11-27T08:51:55.157Z      1.764234e+09   1.8 -63.684  16.300
# 68189  2025-11-27T08:51:55.246Z      1.764234e+09   1.7 -40.775  16.300
#
#            TWD  BelowLineCalc  central    COG  COG_Mag  ...  M_back_X  \
# 58758  349.120            NaN   82.100  322.2    319.2  ...  2807.496
# 58759  349.164            NaN   71.100  321.6    318.6  ...  4005.835
# 58760  349.203            NaN   80.500  321.6    318.6  ...  3847.270
# 58761  349.243            NaN   82.881  321.8    318.8  ...  4145.986
# 58762  349.278            NaN   85.000  322.6    319.6  ...  5525.602
# ...        ...            ...      ...    ...      ...  ...       ...
# 68185  343.086            NaN      NaN   79.1     76.1  ...   -87.031
# 68186  343.095            NaN      NaN   62.7     59.7  ...   -86.419
# 68187  343.107            NaN      NaN   46.3     43.3  ...   -83.598
# 68188  343.116            NaN      NaN   46.8     43.8  ...   -80.942
# 68189  343.125            NaN      NaN   23.9     20.9  ...   -79.410
#
#        M_back_Y  M_front_X  M_front_Y    M_tot_X   M_tot_Y  P_back_X  \
# 58758  -733.093   6147.995  -1134.361   8955.490 -3270.125   -11.159
# 58759  -963.817   6131.165  -1559.944  10137.000 -3392.100   -12.529
# 58760  -940.469   6555.186   -968.326  10402.455 -2394.055   -12.545
# 58761 -1060.056   7006.953    174.805  11152.938 -2845.079   -17.382
# 58762 -1271.017   8318.571   1618.972  13844.174 -2356.451   -20.793
# ...         ...        ...        ...        ...       ...       ...
# 68185    -2.374   -350.068   -235.111   -437.098 -1334.900    -1.813
# 68186    -2.422   -351.057   -234.743   -437.476 -1318.955    -1.820
# 68187    -2.047   -351.206   -234.652   -434.804 -1302.958    -1.517
# 68188    -1.609   -348.950   -235.339   -429.892 -1288.256    -1.186
# 68189    -2.074   -346.030   -235.145   -425.440 -1263.807    -1.531
#
#        P_back_Y  P_front_X  P_front_Y
# 58758   -43.937    -17.103    -98.533
# 58759   -51.974    -22.322    -87.893
# 58760   -51.309    -14.219    -96.502
# 58761   -67.984      2.882   -117.535
# 58762   -90.193     25.742   -132.332
# ...         ...        ...        ...
# 68185    66.459    -64.461     95.981
# 68186    64.951    -64.684     96.738
# 68187    61.980    -65.033     97.335
# 68188    59.707    -65.778     97.526
# 68189    58.436    -66.812     98.319
#
# [5254 rows x 75 columns]
# T-statistic: 3.624, p-value: 0.000290543259407
# The difference is statistically significant, keeping data split.
#
#  Gian on chub downwind VS Gian on levi downwind:
# Mean mast_brand on the first group : Levi, average SOG: 25.62, std SOG: 6.01
# Mean  mast_brand on the second group : Chub, average SOG: 25.25, std SOG: 5.78

# %%
Only_Max_Day3.head()
# Out:
#                  ISODateTimeUTC  SecondsSince1970   SOG     TWA     TWS  \
# 49001  2025-11-27T07:52:53.960Z      1.764230e+09  21.6  32.496  15.396
# 49002  2025-11-27T07:52:54.056Z      1.764230e+09  21.7  34.900  15.400
# 49003  2025-11-27T07:52:54.160Z      1.764230e+09  21.7  34.500  15.400
# 49004  2025-11-27T07:52:54.260Z      1.764230e+09  21.7  32.500  15.400
# 49005  2025-11-27T07:52:54.359Z      1.764230e+09  21.6  32.100  15.400
#
#          TWD  BelowLineCalc  central    COG  COG_Mag  ...  M_back_X  M_back_Y  \
# 49001  0.896            NaN   89.826  328.4    325.4  ...  2198.970  -887.590
# 49002  0.900            NaN  103.200  326.0    323.0  ...  2738.451  -904.930
# 49003  0.900            NaN  122.400  326.4    323.4  ...  2814.371  -766.763
# 49004  0.900            NaN  143.100  328.4    325.4  ...  1580.537  -732.887
# 49005  0.900            NaN  141.500  328.8    325.8  ...  1647.522  -760.783
#
#        M_front_X  M_front_Y    M_tot_X   M_tot_Y  P_back_X  P_back_Y  \
# 49001   8588.561    701.205  10787.530   829.780   -12.088   -28.808
# 49002   9236.083    827.462  11974.535  1542.661   -10.806   -32.355
# 49003   8342.548   -241.699  11156.919  3325.833    -8.433   -30.901
# 49004   8199.257    -63.678   9779.794  2148.543    -8.880   -19.150
# 49005   7784.125   -210.238   9431.646  1007.138    -9.866   -21.372
#
#        P_front_X  P_front_Y
# 49001     10.510   -130.801
# 49002     11.240   -125.999
# 49003     -3.429   -115.323
# 49004     -0.929   -120.505
# 49005     -3.501   -119.271
#
# [5 rows x 75 columns]
