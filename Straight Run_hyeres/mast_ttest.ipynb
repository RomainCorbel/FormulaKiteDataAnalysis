# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import scipy.stats as stats

def t_test(df1, df2, target="SOG"):
    t_stat, p_value = stats.ttest_ind(df1[target].dropna(), df2[target].dropna())
    print(f"T-statistic: {t_stat:.3f}, p-value: {p_value:.15f}")
    
    # If p-value is less than 0.05, the difference is statistically significant
    if p_value < 0.05:
        print("The difference is statistically significant, keeping data split.")
    else:
        print("The difference is not statistically significant, keeping data combined.")

def print_run_stats(first_sentence, first_runs_df, last_runs_df, target):
    print("\n", first_sentence)

    if first_runs_df[target].dtype == "O":
        first_target = ", ".join(first_runs_df[target].dropna().unique())
        last_target = ", ".join(last_runs_df[target].dropna().unique())
    else:
        first_target = f"{first_runs_df[target].mean():.2f}"
        last_target = f"{last_runs_df[target].mean():.2f}"

    print(f"Mean {target } on the first group : {first_target}, "
          f"average SOG: {first_runs_df['SOG'].mean():.2f}, std SOG: {first_runs_df['SOG'].std():.2f}")
    
    print(f"Mean  {target } on the second group : {last_target}, "
          f"average SOG: {last_runs_df['SOG'].mean():.2f}, std SOG: {last_runs_df['SOG'].std():.2f}")

# %%
df = pd.read_csv("all_data.csv")
# Out:
# C:\Users\romai\AppData\Local\Temp\ipykernel_36120\2979013382.py:1: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("all_data.csv")

# %%
data_25_11 = df[df["ISODateTimeUTC"].str.startswith("2025-11-25")]
data_26_11 = df[df["ISODateTimeUTC"].str.startswith("2025-11-26")]
data_27_11 = df[df["ISODateTimeUTC"].str.startswith("2025-11-27")]

# %%
t_test(data_25_11,data_26_11, target="TWS")
print_run_stats("Runs 1 to 5 VS Runs 6 to 10:", data_25_11, data_26_11, target="TWS")
# Out:
# T-statistic: 201.068, p-value: 0.000000000000000
# The difference is statistically significant, keeping data split.
#
#  Runs 1 to 5 VS Runs 6 to 10:
# Mean TWS on the first group : 22.42, average SOG: 22.02, std SOG: 2.61
# Mean  TWS on the second group : 15.81, average SOG: 26.67, std SOG: 4.71

# %%
t_test(data_27_11,data_26_11, target="TWS")
print_run_stats("Runs 1 to 5 VS Runs 6 to 10:", data_27_11, data_26_11, target="TWS")
# Out:
# T-statistic: -99.484, p-value: 0.000000000000000
# The difference is statistically significant, keeping data split.
#
#  Runs 1 to 5 VS Runs 6 to 10:
# Mean TWS on the first group : 14.17, average SOG: 26.69, std SOG: 4.42
# Mean  TWS on the second group : 15.81, average SOG: 26.67, std SOG: 4.71

# %% [markdown]
# ## t test Max levi vs karl chub per day

# %%
Only_Max_Day1 = data_25_11[(data_25_11["boat_name"] == "Max Maeder")]
Only_Max_Day1["boat_name"].sample(5)

Only_Max_Day2 = data_26_11[(data_26_11["boat_name"] == "Max Maeder")]
Only_Max_Day2["boat_name"].sample(5)

Only_Max_Day3 = data_27_11[(data_27_11["boat_name"] == "Max Maeder")]
Only_Max_Day3["boat_name"].sample(5)
# Out:
# 45018    Max Maeder
# 48221    Max Maeder
# 52637    Max Maeder
# 42201    Max Maeder
# 56106    Max Maeder
# Name: boat_name, dtype: object

# %%
Only_Max_Day1_Levi = Only_Max_Day1[Only_Max_Day1["mast_brand"] == "Levi"]
Only_Max_Day1_Chub = Only_Max_Day1[Only_Max_Day1["mast_brand"] == "Chub"]
t_test(Only_Max_Day1_Levi,Only_Max_Day1_Chub) #upwind
print_run_stats("Gian on chub downwind VS Gian on levi downwind:", Only_Max_Day1_Levi, Only_Max_Day1_Chub, target="mast_brand")
# Out:
# T-statistic: -15.735, p-value: 0.000000000000000
# The difference is statistically significant, keeping data split.
#
#  Gian on chub downwind VS Gian on levi downwind:
# Mean mast_brand on the first group : Levi, average SOG: 21.58, std SOG: 0.74
# Mean  mast_brand on the second group : Chub, average SOG: 22.91, std SOG: 3.94

# %%
Only_Max_Day2_Levi = Only_Max_Day2[Only_Max_Day2["mast_brand"] == "Levi"]
Only_Max_Day2_Chub = Only_Max_Day2[Only_Max_Day2["mast_brand"] == "Chub"]
t_test(Only_Max_Day2_Levi,Only_Max_Day2_Chub) #upwind
print_run_stats("Gian on chub downwind VS Gian on levi downwind:", Only_Max_Day2_Levi, Only_Max_Day2_Chub, target="mast_brand")
# Out:
# T-statistic: 13.061, p-value: 0.000000000000000
# The difference is statistically significant, keeping data split.
#
#  Gian on chub downwind VS Gian on levi downwind:
# Mean mast_brand on the first group : Levi, average SOG: 27.32, std SOG: 5.12
# Mean  mast_brand on the second group : Chub, average SOG: 26.35, std SOG: 4.68

# %%
Only_Max_Day3_Levi = Only_Max_Day3[Only_Max_Day3["mast_brand"] == "Levi"]
print(Only_Max_Day3_Levi)
Only_Max_Day3_Chub = Only_Max_Day3[Only_Max_Day3["mast_brand"] == "Chub"]
print(Only_Max_Day3_Chub)
t_test(Only_Max_Day3_Levi,Only_Max_Day3_Chub) #upwind
print_run_stats("Gian on chub downwind VS Gian on levi downwind:", Only_Max_Day3_Levi, Only_Max_Day3_Chub, target="mast_brand")
# Out:
# Empty DataFrame
# Columns: [ISODateTimeUTC, SecondsSince1970, SOG, TWA, TWS, TWD, BelowLineCalc, central, COG, COG_Mag, DistanceToLeader, Heel, Heel_Abs, Heel_Lwd, Lat, LatBow, LatCenter, lateral, LatStern, Leg, Log, LogAlongCourse, Lon, LonBow, LonCenter, LonStern, MagneticVariation, Rank, ROT, TimeLocal, TimeUTC, Trim, TWA_Abs, VMC, VMG, XTE, run, interval_id, boat_name, opponent_name, boat_role, boat_weight, interval_duration, mast_brand, load_cell, gain_forward, gain_lateral, gain_vmg, Line_R2, Line_L2, Line_C2, side_line2, total_line2]
# Index: []
#
# [0 rows x 53 columns]
# Empty DataFrame
# Columns: [ISODateTimeUTC, SecondsSince1970, SOG, TWA, TWS, TWD, BelowLineCalc, central, COG, COG_Mag, DistanceToLeader, Heel, Heel_Abs, Heel_Lwd, Lat, LatBow, LatCenter, lateral, LatStern, Leg, Log, LogAlongCourse, Lon, LonBow, LonCenter, LonStern, MagneticVariation, Rank, ROT, TimeLocal, TimeUTC, Trim, TWA_Abs, VMC, VMG, XTE, run, interval_id, boat_name, opponent_name, boat_role, boat_weight, interval_duration, mast_brand, load_cell, gain_forward, gain_lateral, gain_vmg, Line_R2, Line_L2, Line_C2, side_line2, total_line2]
# Index: []
#
# [0 rows x 53 columns]
#                  ISODateTimeUTC  SecondsSince1970   SOG      TWA     TWS  \
# 40914  2025-11-27T07:52:59.062Z      1.764230e+09  22.2   39.312  15.712
# 40915  2025-11-27T07:52:59.157Z      1.764230e+09  22.5   37.732  15.732
# 40916  2025-11-27T07:52:59.265Z      1.764230e+09  22.4   39.453  15.753
# 40917  2025-11-27T07:52:59.357Z      1.764230e+09  22.5   37.071  15.771
# 40918  2025-11-27T07:52:59.463Z      1.764230e+09  22.3   34.393  15.793
# ...                         ...               ...   ...      ...     ...
# 64542  2025-11-27T09:27:56.855Z      1.764236e+09  30.6 -154.186  14.573
# 64543  2025-11-27T09:27:56.956Z      1.764236e+09  30.6 -154.096  14.521
# 64544  2025-11-27T09:27:57.052Z      1.764236e+09  30.5 -153.100  14.500
# 64545  2025-11-27T09:27:57.157Z      1.764236e+09  30.6 -153.900  14.500
# 64546  2025-11-27T09:27:57.256Z      1.764236e+09  30.5 -153.200  14.500
#
#            TWD  BelowLineCalc  central    COG  COG_Mag  ...  mast_brand  \
# 40914    0.812            NaN   130.10  321.5    318.5  ...         NaN
# 40915    0.832            NaN   117.20  323.1    320.1  ...         NaN
# 40916    0.853            NaN   107.30  321.4    318.4  ...         NaN
# 40917    0.871            NaN   104.93  323.8    320.8  ...         NaN
# 40918    0.893            NaN   102.20  326.5    323.5  ...         NaN
# ...        ...            ...      ...    ...      ...  ...         ...
# 64542  332.615            NaN    74.50  126.8    123.8  ...         NaN
# 64543  332.604            NaN    72.60  126.7    123.7  ...         NaN
# 64544  332.600            NaN    76.60  125.7    122.7  ...         NaN
# 64545  332.600            NaN    77.70  126.5    123.5  ...         NaN
# 64546  332.600            NaN    77.90  125.8    122.8  ...         NaN
#
#        load_cell  gain_forward  gain_lateral  gain_vmg   Line_R2   Line_L2  \
# 40914        NaN           NaN           NaN       NaN  5.400000  5.400000
# 40915        NaN      0.058145     -0.129842 -0.035376  5.400000  5.400000
# 40916        NaN      0.143965     -0.238510 -0.037410  6.900000  6.900000
# 40917        NaN      1.305453     -0.145659  0.932728  7.200000  7.200000
# 40918        NaN      0.305754     -0.390991  0.003750  7.200000  7.200000
# ...          ...           ...           ...       ...       ...       ...
# 64542        NaN     -0.898476     -4.523054 -0.683873  7.900000  7.900000
# 64543        NaN     -0.908113     -4.361287 -0.620980  7.925436  7.925436
# 64544        NaN     -0.907915     -4.174557 -0.558964  7.949127  7.949127
# 64545        NaN     -0.921090     -3.985452 -0.483373  7.975561  7.975561
# 64546        NaN     -0.935734     -3.736034 -0.385970  8.000000  8.000000
#
#        Line_C2  side_line2  total_line2
# 40914   130.10   10.800000   140.900000
# 40915   117.20   10.800000   128.000000
# 40916   107.30   13.800000   121.100000
# 40917   104.93   14.400000   119.330000
# 40918   102.20   14.400000   116.600000
# ...        ...         ...          ...
# 64542    74.50   15.800000    90.300000
# 64543    72.60   15.850873    88.450873
# 64544    76.60   15.898254    92.498254
# 64545    77.70   15.951122    93.651122
# 64546    77.90   16.000000    93.900000
#
# [12112 rows x 53 columns]
# T-statistic: nan, p-value: nan
# The difference is not statistically significant, keeping data combined.
#
#  Gian on chub downwind VS Gian on levi downwind:
# Mean mast_brand on the first group : , average SOG: nan, std SOG: nan
# Mean  mast_brand on the second group : , average SOG: nan, std SOG: nan
# c:\Users\romai\anaconda3\envs\sail2\lib\site-packages\scipy\_lib\deprecation.py:234: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   return f(*args, **kwargs)

# %%
Only_Max_Day3.head()
# Out:
#                  ISODateTimeUTC  SecondsSince1970   SOG     TWA     TWS  \
# 40914  2025-11-27T07:52:59.062Z      1.764230e+09  22.2  39.312  15.712
# 40915  2025-11-27T07:52:59.157Z      1.764230e+09  22.5  37.732  15.732
# 40916  2025-11-27T07:52:59.265Z      1.764230e+09  22.4  39.453  15.753
# 40917  2025-11-27T07:52:59.357Z      1.764230e+09  22.5  37.071  15.771
# 40918  2025-11-27T07:52:59.463Z      1.764230e+09  22.3  34.393  15.793
#
#          TWD  BelowLineCalc  central    COG  COG_Mag  ...  mast_brand  \
# 40914  0.812            NaN   130.10  321.5    318.5  ...         NaN
# 40915  0.832            NaN   117.20  323.1    320.1  ...         NaN
# 40916  0.853            NaN   107.30  321.4    318.4  ...         NaN
# 40917  0.871            NaN   104.93  323.8    320.8  ...         NaN
# 40918  0.893            NaN   102.20  326.5    323.5  ...         NaN
#
#        load_cell  gain_forward  gain_lateral  gain_vmg  Line_R2  Line_L2  \
# 40914        NaN           NaN           NaN       NaN      5.4      5.4
# 40915        NaN      0.058145     -0.129842 -0.035376      5.4      5.4
# 40916        NaN      0.143965     -0.238510 -0.037410      6.9      6.9
# 40917        NaN      1.305453     -0.145659  0.932728      7.2      7.2
# 40918        NaN      0.305754     -0.390991  0.003750      7.2      7.2
#
#        Line_C2  side_line2  total_line2
# 40914   130.10        10.8       140.90
# 40915   117.20        10.8       128.00
# 40916   107.30        13.8       121.10
# 40917   104.93        14.4       119.33
# 40918   102.20        14.4       116.60
#
# [5 rows x 53 columns]
